# %% [markdown]
# RNN 是专门用来处理“一串”数据的神经网络。它最大的贡献是提出了“循环反馈”的结构，但它最大的弱点是“记性不好”（梯度消失）。
# 后来为了解决这个问题，才有了LSTM和GRU（长短期记忆网络），它们是RNN的进化版。

# %% [markdown]
# Rnn处理序列输入数据
#
# RNN出现梯度消失，核心原因在于反向传播时，梯度需要反复乘以同一个权重矩阵。这个连乘过程导致梯度呈指数级衰减。
# ![image.png](attachment:5eb8c362-986c-466e-aa42-0b4f8b4f41d8.png)

# %% [markdown]
# ![image.png](attachment:db0b3f17-7ea5-45a1-a364-64c177b17f02.png)
